# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreasKing-Goks/MIR_Deep_Learning/blob/main/TP_Object_Detectionv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection in a maritime context
#
# ## Introduction
#
# In this lab we want to go deeper into the comprehension and the use of object detection architectures by training maritime object detectors. We will start by training a Faster R-CNN object detector on a maritime Pascal VOC subset. Then we will redefine our need to retrain the model in a more efficient fashion. Then we'll analyse the performance of the model using metrics seen in class.
#
# ## Objectives
# - Learn to use an object detector in pytorch and evaluate it.
# - Select data and train a detector to meet an industry requirement.
#
# ## Getting started
#
# Load all the necessary packages before starting.

# %%
# import torch packages
import pandas as pd 
import torch
import torch.nn as nn
import os
import time
from pathlib import Path
from torch.autograd import Variable
import PIL
from PIL import Image
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# import some common libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files, drive

# %% [markdown]
# ## Exercise 1: What is the challenge ?
#
# For the Unmanned Surface Vehicle (USV) we want to be able to detect all surrounding floating objects and classify them into one of the following categories.
#
# 0. boat
# 1. buoy
# 2. sail
# 3. person
# 4. kayak
# 5. motor_sail
# 6. ferry
# 7. vessel
# 8. zodiac
# 9. fishing_boat
# 10. OFNI
# 11. kite
# 12. windsurf
# 13. surfboard
#
# For that purpose Eca Robotics has downloaded [Pascal VOC](http://host.robots.ox.ac.uk/pascal/VOC/) open dataset, filter only maritime images and reannotate them with interesting classes. Indeed Pascal VOC dataset only contains 20 categories and we kept images containing boat objects.
#
# **Can you train a maritime object detector with that dataset ?**
#
# Load the data and create stats on the classes to get a sense of the dataset.

# %%
# !gdown 1ik0v3VJosH9E_UX62nGxl-hi75t36knJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ik0v3VJosH9E_UX62nGxl-hi75t36knJ
# To: /content/maritime_object_detection.tar
# 100% 59.6M/59.6M [00:00<00:00, 230MB/s]

# %%
# !tar -xf maritime_object_detection.tar

# %%
data_path = 'pascal_voc/train/'

# Create annotations dictionnary
anno_dict = {
    0: "boat",
    1: "buoy",
    2: "sail",
    3: "person",
    4: "kayak",
    5: "motor_sail",
    6: "ferry",
    7: "vessel",
    8: "zodiac",
    9: "fishing_boat",
    10: "OFNI",
    11: "kite",
    12: "windsurf",
    13: "surfboard"
}

# %% [markdown]
# We show an image to see the nature of the images.

# %%
from PIL import Image
Image.open(data_path + '2007_000061.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FB606F4C100>

# %% [markdown]
# We want to count the number of occurences of each class in the 500+ files we have at our disposal.
#
# ```
# TODO
# 1. read all txt files and iterate over them - Path and glob function,
# 2. filter labels.txt file,
# 3. using pandas to read column 0 and append it to the classes list,
# 4. concat the list into a pandas dataframe,
# 5. return the count using value_counts function
# ```

# %%
# Get annotations from txt files
def count_objects(data_path):
  """
  Function reading all yolo format txt files and returning number of objects by class

  <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
  <object-class> - integer number of object from 0 to (classes-1)
  <XCenterRelative> <YCenterRelative> - center of the bounding box [0,1]
  <WidthRelative> <HeightRelative> - width and height [0,1]
  """
  # Create class container
  classes = []

  ### BEGIN SOLUTION
  
  # Iterate over text file in a sorted list of files in a folder
  for filename in sorted(os.listdir(data_path)):
  
    # Check if the file format is '.txt' and is not the 'labels.txt', then create the file path
    if filename.endswith("txt") and filename != 'labels.txt': 
      file_path = data_path + filename

      # Iterate over the line in an opened txt.file
      with open(file_path) as f:
        lines = f.readlines()

        # Iterate over each line to get the class, then append it to the classes list
        for line in lines:
          im_class = line.split()[0]
          classes.append(int(im_class))
  
  # Convert classes list to dataframe
  df = pd.DataFrame(classes)

  return df.value_counts()

  ### END SOLUTION

# %%
count_df = count_objects(data_path)
# If assert launch an error there is an error in your code, else it is OK.
assert len(count_df) == 14
count_df
# Out:
# 3     572
# 0     416
# 4     170
# 2     165
# 1     149
# 5     139
# 6     113
# 7      66
# 9      55
# 8      37
# 10      8
# 12      3
# 11      2
# 13      1
# dtype: int64

# %% [markdown]
# To improve readability replace index by class names using the dictionnary anno_dict.
#
# ```
# TODO
# Replace index by class names with one command
# ```
#
# Hint : Use pandas.rename function.

# %%
### BEGIN SOLUTION
count_df = count_df.rename(index=anno_dict)
### END SOLUTION
assert count_df['sail'] == 165
count_df
# Out:
# person          572
# boat            416
# kayak           170
# sail            165
# buoy            149
# motor_sail      139
# ferry           113
# vessel           66
# fishing_boat     55
# zodiac           37
# OFNI              8
# windsurf          3
# kite              2
# surfboard         1
# dtype: int64

# %% [markdown]
# To improve the effectiveness of the TP we use a small dataset, which is still long to train. Futhermore the dataset is unbalanced, which is a difficulty to train a robust detector.
#
# In industrial applications several thousands of annotations by class are needed to obtain an acceptable performance. We'll keep that in mind when analysing results.

# %% [markdown]
# ## Exercise 2: Code a dataloader
#
# To exploit the images and their annotations, we need to write a dataloader in order to iterate through the images in the Pytorch format.
#
# The [torchvision reference scripts for training object detection, instance segmentation and person keypoint detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#     * (optionally) `masks` (`UInt8Tensor[N, H, W]`): The segmentation masks for each one of the objects
#     * (optionally) `keypoints` (`FloatTensor[N, K, 3]`): For each one of the `N` objects, it contains the `K` keypoints in `[x, y, visibility]` format, defining the object. `visibility=0` means that the keypoint is not visible. Note that for data augmentation, the notion of flipping a keypoint is dependent on the data representation, and you should probably adapt `references/detection/transforms.py` for your new keypoint representation
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
#
# One note on the labels. The model considers class 0 as background. **Then we need to modify class 0 - boat, in order to make a difference from the background. We will replace 0 by 14.**
#
# ```
# TODO
# Implement __getitem__ function by following comments in the code
# ```

# %%
class VocDataset(torch.utils.data.Dataset):
  def __init__(self, root, transform=None):
    self.root = root
    self.transform = transform
    # load all image files, sorting them to ensure that they are aligned
    self.imgs = list(sorted(Path(root).glob('*.jpg')))
    self.bboxes = list(sorted(Path(root).glob('*.txt')))[:-1] # ignore labels.txt


  def __getitem__(self, idx):

    # BEGIN SOLUTION

    # get image and bounding boxes paths
    img_path = self.imgs[idx]
    bbox_path = self.bboxes[idx]
    # open image and convert to RGB
    img = Image.open(img_path).convert('RGB')
    # get width and height
    width, height = img.size
    # get bounding boxes
    bbox_df = pd.DataFrame(pd.read_csv((bbox_path), delimiter = ' ', header = None))

    # get bounding box coordinates
    # YOLO format reminder :
    # <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
    boxes = []
    for index, row in bbox_df.iterrows():
      xmin = (row[1] - (row[3]/2))*width
      xmax = (row[1] + (row[3]/2))*width
      ymin = (row[2] - (row[4]/2))*height
      ymax = (row[2] + (row[4]/2))*height
      if xmin < xmax and ymin < ymax:
        boxes.append([xmin, ymin, xmax, ymax])

    # convert everything into a torch.Tensor
    boxes = torch.Tensor(boxes)
    # replace label 0 by 14
    labels = bbox_df.loc[:,0].replace(0, 14)
    # convert labels to a torch.Tensor
    labels = torch.Tensor(labels).type(torch.int64)
    # get image id
    image_id = torch.Tensor([idx]).type(torch.int64)
    # compute area of the bounding boxes
    area = torch.tensor([(boxes[row,2]-boxes[row,0])*(boxes[row,3]-boxes[row,1]) for row in range(boxes.size(dim=0))])
    # suppose all instances are not crowd
    iscrowd = torch.zeros((len(bbox_df),), dtype=torch.int64)

    # populate target dictionnary
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = image_id
    target["area"] = area
    target["iscrowd"] = iscrowd

    ### END SOLUTION

    # image transformation
    if self.transform is not None:
      img, target = self.transform(img, target)

    return img, target


  def __len__(self):
    return len(self.imgs)

# %% [markdown]
# Let now get the result tuple for the first image and plot it with ground truth annotations to see if the data seems correctly read.

# %%
dataset = VocDataset(data_path)
assert torch.equal(dataset[2][1]['area'], torch.tensor([22363.4668]))
assert torch.equal(dataset[1][1]['labels'], torch.tensor([14, 5, 14]))
dataset[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=500x333 at 0x7FB57741FE20>,
#  {'boxes': tensor([[274.0000,  10.9998, 437.0000, 278.9999],
#           [187.3420, 214.0001, 281.0000, 252.0001]]),
#   'labels': tensor([5, 6]),
#   'image_id': tensor([0]),
#   'area': tensor([43684.0117,  3559.0000]),
#   'iscrowd': tensor([0, 0])})

# %%
import torchvision.transforms.functional as F

plt.rcParams["savefig.bbox"] = 'tight'

def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
from torchvision.io import read_image
from torchvision.utils import draw_bounding_boxes

img1_int = read_image(data_path + '/2007_000061.jpg')
colors = ["yellow", "red"]
result = draw_bounding_boxes(img1_int, dataset[0][1]['boxes'], colors=colors, width=5)
show(result)

# %%
img2_int = read_image(data_path + '/2007_000241.jpg')
colors = ["blue", "yellow", "blue"]
result = draw_bounding_boxes(img2_int, dataset[1][1]['boxes'], colors=colors, width=5)
show(result)

# %% [markdown]
# The dataloader seems to do the job. If you are curious about the dataset you can plot other images, or create a grib with several ones.

# %% [markdown]
# ## Exercise 3: Define a model
#
# In this tutorial, we will be using faster R-CNN as described in class. Faster R-CNN is a model that predicts both bounding boxes and class scores for potential objects in the image.
#
# ![Faster R-CNN](https://www.researchgate.net/profile/Zhipeng-Deng-2/publication/324903264/figure/fig2/AS:640145124499471@1529633899620/The-architecture-of-Faster-R-CNN.png)
#
# There are two common situations where one might want to modify one of the available models in torchvision modelzoo. The first is when we want to start from a pre-trained model, and just finetune the last layer. The other is when we want to replace the backbone of the model with a different one (for faster predictions, for example).
#
# We are in the first case to use all the power of a pretrained model. We'll load Faster R-CNN with pretrained weights before retraining it on the images we have. By that means we accelerate the training of the model.
#
# ```
# TODO
# 1. load a pretrained fasterrcnn_resnet50_fpn
# 2. get number of input features for the classifier
# 3. replace the pre-trained head with a new one
# ```

# %%
def get_detection_model(num_classes=15):

  ### BEGIN SOLUTION

  # load a model pre-trained on COCO
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights='COCO_V1')
  # get number of input features for the classifier
  in_features = model.roi_heads.box_predictor.bbox_pred.in_features
  # replace the pre-trained head with a new one
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features,num_classes)

  ### END SOLUTION

  return model

# %%
## PERSONAL COMMENT
# Replacing the FastRCNNPredictor layer to change the output feature for the class score. It also automatically change the output feature of the bbox_pred.

# %% [markdown]
# ## Exercise 4: Preparing training loop
#
# In references/detection/, we have a number of helper functions to simplify training and evaluating detection models. Here, we will use references/detection/engine.py, references/detection/utils.py and references/detection/transforms.py.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.8.2
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# HEAD is now at 2f40a483d7 [v0.8.X] .circleci: Add Python 3.9 to CI (#3063)

# %% [markdown]
# ### Data augmentation
#
# To go deeper into the training process we want to do data augmentation by applying random transformations to the images. It allows the model to train longer without overfitting and augment programmatically the dataset size and the genericity of the model.
#
# You can find the reference of the transformations here: https://pytorch.org/vision/stable/transforms.html

# %%
import transforms as T

def get_transform(train):
    transform = []
    # converts the image, a PIL image, into a PyTorch Tensor
    # transform.append(transforms.ToTensor())
    transform.append(T.ToTensor())
    if train:

      ### BEGIN SOLUTION

      # during training randomly horizontal flip the training images - proba 0.5
      transform.append(T.RandomHorizontalFlip(0.5))

      ## END SOLUTION

    return T.Compose(transform)

# %% [markdown]
# ### Testing forward() method
#
# Before iterating over the dataset, it’s good to see what the model expects during training and inference time on sample data.
#
# ```
# TODO
# Follow the comments on the next cell
# ```

# %%
import utils

### BEGIN SOLUTION

# get model and dataset with augmentations
model = get_detection_model()
dataset = VocDataset(data_path, get_transform(train=True))

# create dataloader with torch.utils.data.DataLoader
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn
)

# For training
# get next batch images + targets by iterating on the data_loader
images, targets = next(iter(data_loader))
# Convert images and targets into the desired format by the model
# Hint : use list comprehension
images = [image for image in images]   # look expected images values https://pytorch.org/vision/main/models/generated/torchvision.models.detection.fasterrcnn_resnet50_fpn.html#torchvision.models.detection.fasterrcnn_resnet50_fpn
targets = [target for target in targets]  # look expected targets values https://pytorch.org/vision/main/models/generated/torchvision.models.detection.fasterrcnn_resnet50_fpn.html#torchvision.models.detection.fasterrcnn_resnet50_fpn
output = model(images, targets)  # Returns losses and detections

### END SOLUTION

# %%
# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x) # Returns predictions
predictions
# Out:
# [{'boxes': tensor([[140.6663, 226.6895, 144.8766, 232.9273],
#           [261.6911,   0.0000, 392.7325, 288.2107],
#           [ 13.5670,  41.2411, 217.9096, 119.1049],
#           [203.3991,  71.1906, 394.5061, 204.9122],
#           [ 71.1099,  49.8167, 278.2589, 137.9194],
#           [177.5983,  42.3419, 360.5406, 173.1026],
#           [ 52.3217,  60.4437,  55.5212,  63.8702],
#           [266.5378, 215.4076, 270.8062, 220.6848],
#           [103.3299, 110.7776, 107.5266, 115.1904],
#           [279.8747,  60.2167, 283.6239,  63.5317],
#           [265.4962, 214.4584, 269.4708, 220.1704],
#           [269.9214, 229.9912, 273.6645, 234.6517],
#           [ 84.5856,  71.0947,  89.4418,  75.4653],
#           [274.2312, 133.2116, 278.5142, 137.7122],
#           [  0.0000,   0.0000, 196.3629, 219.0540],
#           [140.8103, 179.0800, 145.1156, 187.0975],
#           [268.4710, 229.7877, 272.1349, 234.2965],
#           [209.8440, 120.6434, 213.8934, 124.9193],
#           [269.8268, 228.3917, 273.4714, 232.8082],
#           [102.1223, 110.5753, 106.1229, 115.2260],
#           [276.2822, 129.0317, 280.2900, 134.2011],
#           [270.9759, 228.2866, 274.6827, 232.7338],
#           [119.9222,  85.8850, 123.4483,  89.7895],
#           [340.3763, 183.7840, 344.5706, 188.1162],
#           [130.1948,  96.7794, 134.0268, 101.4069],
#           [113.2013,  93.2824, 117.6238,  98.1530],
#           [138.7431, 103.6793, 143.1644, 108.7525],
#           [274.1458, 225.6354, 278.2107, 230.1898],
#           [121.3353,  85.5651, 124.9743,  89.4044],
#           [267.6564, 224.8241, 271.7933, 229.1723],
#           [338.8456, 183.9659, 343.0855, 188.2111],
#           [267.5036, 216.3208, 272.0223, 221.1471],
#           [132.5154, 143.8910, 136.3893, 148.4981],
#           [141.6438,  89.0382, 362.6477, 160.5269],
#           [  0.0000,   0.0000, 290.9317, 111.3326],
#           [113.9495, 194.0591, 117.2749, 198.1409],
#           [278.5045,  60.7353, 282.0447,  64.1869],
#           [122.5234,  85.6782, 126.1949,  89.4883],
#           [206.5573, 180.5512, 397.4589, 253.8967],
#           [ 96.2724, 206.1379,  99.9302, 209.9515],
#           [268.9851, 216.4080, 273.4399, 220.9545],
#           [113.9093, 192.3185, 117.2265, 196.3220],
#           [120.3223,  33.8316, 307.0870, 161.9320],
#           [ 89.6269, 152.1547,  93.5135, 156.5854],
#           [272.9195, 226.4637, 276.7753, 230.8949],
#           [120.0049,  84.5328, 123.4614,  88.4863],
#           [137.6150, 102.5792, 142.1629, 107.5965],
#           [ 74.7405,  70.6759,  78.8643,  75.5278],
#           [124.4352,  87.6697, 127.9026,  91.4803],
#           [ 70.7552, 130.5180,  74.6552, 135.0777],
#           [251.4717, 226.7601, 255.6140, 232.0263],
#           [ 85.4466, 161.9082,  88.8461, 166.2253],
#           [312.3630, 217.6782, 316.3212, 222.1602],
#           [276.6675,  67.5754, 367.4175, 225.9312],
#           [272.4416, 227.5682, 276.1357, 231.8877],
#           [162.6966, 183.9877, 166.6885, 189.4057],
#           [167.1787, 120.1209, 171.4924, 124.9929],
#           [266.0020, 224.9016, 269.8295, 229.1177],
#           [138.2704, 101.1953, 143.5069, 105.9792],
#           [191.6499, 193.3130, 195.5519, 197.7475],
#           [270.6862, 230.8961, 274.5479, 235.5181],
#           [119.6087, 106.6915, 123.4682, 110.9530],
#           [ 94.4587, 122.2687, 320.3471, 206.8420],
#           [124.3541,  85.9040, 127.8313,  89.7226],
#           [ 87.2181, 161.3245,  90.7884, 165.6791],
#           [124.3270,  84.4216, 127.7164,  88.2462],
#           [115.0906,  93.8251, 119.2823,  98.6140],
#           [357.8838,  58.9998, 362.1862,  64.1093],
#           [119.9575,  87.1841, 123.6468,  91.1132],
#           [313.3711, 216.8262, 317.3666, 221.4198],
#           [111.2797,  97.3017, 116.1564, 102.3769],
#           [ 77.6265, 126.6760,  81.1423, 130.9199],
#           [ 89.5334, 162.2027,  93.5914, 166.9189],
#           [191.7157, 191.6508, 195.5271, 195.9484],
#           [119.4840, 108.2153, 123.0854, 112.6554],
#           [143.4183, 178.7640, 147.6366, 185.6891],
#           [130.4284, 144.2764, 134.8556, 148.8052],
#           [274.9739, 224.5614, 279.1623, 228.9999],
#           [314.5566, 217.3335, 318.3900, 222.0863],
#           [274.9436, 131.1292, 279.0532, 136.0671],
#           [ 34.4334,  65.1365,  38.0374,  68.9920],
#           [262.0681, 228.5868, 265.6672, 232.1242],
#           [268.3777, 228.3005, 272.0167, 232.5818],
#           [  4.1670,  49.8105, 194.4775, 175.8750],
#           [114.0613, 201.1306, 117.5444, 205.2477],
#           [ 73.8887, 130.4709,  78.5507, 135.3760],
#           [121.3902,  83.9942, 124.9769,  87.9032],
#           [125.7919,  86.3246, 129.1209,  90.0745],
#           [260.8507, 229.5708, 264.6490, 233.4976],
#           [315.0710, 218.6560, 318.6470, 223.3570],
#           [260.8057, 228.0561, 264.4413, 231.6981],
#           [261.0322, 231.2097, 264.9016, 235.4643],
#           [ 96.9220, 207.2948, 100.9412, 211.2986],
#           [278.4899,  62.5494, 281.9783,  66.1326],
#           [327.1225, 220.6158, 331.1543, 225.2979],
#           [158.7855, 184.1966, 162.5943, 189.2130],
#           [269.4144, 226.8236, 273.1756, 230.9916],
#           [111.0600, 161.5863, 117.5490, 165.6400],
#           [ 77.6779, 128.1606,  81.3012, 132.4582],
#           [111.4833,  95.6405, 116.2379, 100.7468]], grad_fn=<StackBackward0>),
#   'labels': tensor([2, 9, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 2, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#           2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#           2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#           2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#           2, 2, 2, 2]),
#   'scores': tensor([0.1359, 0.1354, 0.1350, 0.1319, 0.1306, 0.1304, 0.1304, 0.1298, 0.1293,
#           0.1290, 0.1288, 0.1286, 0.1280, 0.1278, 0.1277, 0.1276, 0.1276, 0.1272,
#           0.1270, 0.1265, 0.1264, 0.1263, 0.1261, 0.1261, 0.1259, 0.1258, 0.1257,
#           0.1256, 0.1255, 0.1255, 0.1253, 0.1248, 0.1247, 0.1246, 0.1245, 0.1239,
#           0.1238, 0.1237, 0.1237, 0.1235, 0.1232, 0.1229, 0.1227, 0.1227, 0.1225,
#           0.1224, 0.1224, 0.1224, 0.1222, 0.1221, 0.1221, 0.1220, 0.1219, 0.1219,
#           0.1219, 0.1218, 0.1217, 0.1217, 0.1216, 0.1216, 0.1212, 0.1212, 0.1211,
#           0.1211, 0.1210, 0.1210, 0.1210, 0.1209, 0.1207, 0.1207, 0.1206, 0.1203,
#           0.1202, 0.1202, 0.1200, 0.1198, 0.1197, 0.1197, 0.1196, 0.1196, 0.1195,
#           0.1194, 0.1193, 0.1192, 0.1191, 0.1190, 0.1189, 0.1188, 0.1188, 0.1187,
#           0.1187, 0.1187, 0.1187, 0.1187, 0.1187, 0.1187, 0.1187, 0.1186, 0.1186,
#           0.1185], grad_fn=<IndexBackward0>)},
#  {'boxes': tensor([[  1.5668,   0.0000,  61.1949, 329.2515],
#           [115.2810, 165.2998, 120.1002, 170.4982],
#           [231.7698, 240.8839, 237.1503, 249.9034],
#           [213.1760, 136.0920, 219.5490, 143.2198],
#           [  0.0000,   0.0000, 156.3180, 389.4024],
#           [146.5641, 372.2997, 151.7879, 377.9088],
#           [279.5564,   0.0000, 392.2547, 371.6911],
#           [225.5660, 158.0316, 230.6458, 163.4158],
#           [177.2151, 172.9562, 182.0676, 179.1945],
#           [145.1904,  92.1392, 391.0909, 215.8680],
#           [113.4092, 165.5119, 118.2928, 170.7183],
#           [144.5368, 373.3436, 150.0630, 379.1242],
#           [317.8998, 390.2462, 321.8937, 395.0301],
#           [177.2951, 175.1877, 182.3167, 181.2543],
#           [316.2575, 390.2600, 320.2025, 395.1981],
#           [227.3936, 169.7390, 232.2270, 175.0248],
#           [227.2397, 158.2068, 232.3392, 163.8864],
#           [126.8252,  82.7447, 132.0884,  87.8908],
#           [222.4932,  77.4084, 353.1534, 283.2604],
#           [141.3946, 374.2019, 148.6902, 379.2158],
#           [231.8190, 157.2212, 236.6831, 163.5064],
#           [225.5740, 160.4528, 230.4724, 166.0812],
#           [269.7701, 158.7195, 275.6341, 164.9850],
#           [273.1815, 156.1602, 279.1471, 162.4713],
#           [126.9443,  81.0386, 132.1602,  85.6111],
#           [137.6181, 372.5525, 142.3338, 377.3699],
#           [124.7831,  83.1771, 129.7778,  88.2956],
#           [142.9009, 375.9025, 148.3140, 381.6623],
#           [317.6918, 392.0853, 321.7932, 397.0123],
#           [225.3876, 171.3686, 230.0391, 176.5477],
#           [271.4013, 157.3819, 277.2287, 163.7916],
#           [287.8963, 221.1423, 327.1544, 254.4923],
#           [  0.0000,   0.0000,  27.4698, 273.3704],
#           [301.3303, 262.1145, 307.1709, 267.6436],
#           [229.6337, 158.6835, 234.6169, 164.7646],
#           [303.1757, 261.2740, 308.3354, 266.7640],
#           [175.1773, 172.8397, 180.1091, 178.9559],
#           [136.0125, 373.7904, 142.2569, 378.3502],
#           [122.8122,  84.3635, 127.8480,  89.2064],
#           [ 26.4121,   0.0000, 272.6157, 349.9964],
#           [  2.4568, 272.4186, 298.8679, 379.2018],
#           [311.5874, 397.0464, 316.5773, 402.8170],
#           [274.9594, 157.7546, 280.7508, 164.2081],
#           [  0.0000,   0.0000, 369.7957,  79.2764],
#           [177.1987, 170.5549, 182.1877, 176.7984],
#           [315.9512, 391.8270, 320.0305, 396.8613],
#           [223.8049, 158.7616, 228.5680, 163.8877],
#           [252.1443, 151.2546, 258.5270, 157.0395],
#           [275.0153, 155.9224, 280.9348, 161.9818],
#           [227.3375, 160.1918, 232.3231, 166.0931],
#           [229.5540, 169.3847, 234.1835, 174.5839],
#           [175.1922, 170.5252, 180.2332, 176.5430],
#           [161.5660, 142.0070, 394.7141, 326.8939],
#           [ 17.1190,  48.4486, 329.1356, 160.2607],
#           [276.9059, 160.3754, 282.3009, 166.1767],
#           [128.0188, 368.1371, 132.6458, 372.5276],
#           [229.3467, 171.9492, 233.7611, 176.9339],
#           [163.2634, 230.0305, 168.3309, 235.8284],
#           [227.3186, 171.7552, 231.8730, 176.7938],
#           [319.5958, 390.5139, 323.4456, 395.2651],
#           [125.9028, 368.4845, 130.5023, 372.9300],
#           [129.3152, 382.1673, 134.0996, 387.5529],
#           [ 50.0537,  96.2287, 168.3660, 291.1451],
#           [145.0137, 366.9613, 151.4108, 373.7774],
#           [177.5854, 408.9055, 390.0220, 479.1789],
#           [231.3624, 244.4354, 236.8788, 255.5289],
#           [325.6219, 388.8382, 329.6232, 393.8626],
#           [279.1270, 159.8649, 284.3011, 165.6266],
#           [139.9594, 374.1200, 145.1505, 379.4289],
#           [207.9428, 185.9081, 212.5913, 191.6020],
#           [124.7916,  81.7705, 129.9262,  86.2234],
#           [328.8900, 160.5599, 333.7189, 165.6170],
#           [177.2812, 177.3130, 182.2241, 183.1511],
#           [254.4335, 151.2585, 260.6249, 156.9221],
#           [123.0615,  82.8346, 128.1475,  87.2614],
#           [323.8835, 389.9987, 328.1603, 394.7022],
#           [239.2222, 175.5607, 244.8129, 182.6703],
#           [230.0888, 243.6164, 235.4610, 252.5427],
#           [361.9868, 203.9483, 397.5114, 474.0710],
#           [273.0193, 159.3878, 278.6244, 165.9688],
#           [  0.0000, 136.9549,  27.9013, 411.0200],
#           [205.8066, 186.5127, 210.6463, 191.7153],
#           [209.5655, 242.6821, 214.0669, 248.1737],
#           [161.8862, 223.2292, 166.5179, 228.0626],
#           [203.6227, 186.3879, 208.5038, 191.4517],
#           [161.1061, 230.4210, 166.1486, 236.9276],
#           [145.0946, 370.7535, 150.8561, 376.7713],
#           [169.3034, 345.3157, 392.9459, 458.9724],
#           [271.4974, 160.4410, 277.3616, 166.5478],
#           [276.2332,  84.2402, 375.7291, 303.7367],
#           [276.8880, 156.8090, 282.7570, 163.1174],
#           [207.8129, 242.5367, 212.6989, 247.7365],
#           [209.7333, 240.1182, 214.2204, 245.5285],
#           [209.6417, 185.4281, 214.0755, 191.3756],
#           [121.5021,  83.7418, 126.5896,  88.2149],
#           [135.7807, 375.6991, 141.9659, 380.3422],
#           [278.6979, 156.4642, 284.3160, 162.6861],
#           [121.5606, 165.1019, 394.5844, 262.2896],
#           [129.7001, 368.4206, 134.4047, 372.8284],
#           [303.6495, 259.0141, 308.7295, 264.3210]], grad_fn=<StackBackward0>),
#   'labels': tensor([5, 2, 2, 2, 5, 2, 9, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 2, 2, 2, 2, 2, 2,
#           7, 2, 7, 2, 2, 2, 2, 2, 5, 2, 2, 2, 2, 2, 7, 5, 2, 2, 2, 5, 2, 2, 2, 2,
#           2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 2, 2, 2, 2, 2, 7, 2,
#           2, 2, 7, 2, 2, 2, 9, 2, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 2,
#           2, 2, 2, 2]),
#   'scores': tensor([0.1514, 0.1391, 0.1385, 0.1384, 0.1358, 0.1355, 0.1348, 0.1345, 0.1345,
#           0.1344, 0.1335, 0.1335, 0.1321, 0.1306, 0.1294, 0.1293, 0.1287, 0.1283,
#           0.1282, 0.1282, 0.1278, 0.1276, 0.1276, 0.1273, 0.1273, 0.1272, 0.1268,
#           0.1267, 0.1265, 0.1265, 0.1265, 0.1263, 0.1263, 0.1262, 0.1258, 0.1257,
#           0.1252, 0.1252, 0.1251, 0.1249, 0.1247, 0.1244, 0.1241, 0.1238, 0.1238,
#           0.1238, 0.1238, 0.1238, 0.1236, 0.1235, 0.1234, 0.1234, 0.1234, 0.1234,
#           0.1233, 0.1233, 0.1232, 0.1232, 0.1231, 0.1231, 0.1231, 0.1230, 0.1229,
#           0.1228, 0.1227, 0.1226, 0.1226, 0.1222, 0.1221, 0.1221, 0.1220, 0.1219,
#           0.1218, 0.1217, 0.1216, 0.1215, 0.1213, 0.1212, 0.1211, 0.1210, 0.1210,
#           0.1210, 0.1208, 0.1207, 0.1205, 0.1205, 0.1204, 0.1204, 0.1202, 0.1202,
#           0.1202, 0.1200, 0.1198, 0.1198, 0.1197, 0.1197, 0.1195, 0.1194, 0.1194,
#           0.1194], grad_fn=<IndexBackward0>)}]

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled internally by the Faster R-CNN model.

# %% [markdown]
# ## Exercise 5: Putting everything together
#
# We now have the dataset class, the model, the data transform and a hint about the dataloader. Let's instantiate them to launch a full training process.
#
# First we want to create train/test split for the training and apply dataloaders to each one.

# %%
from engine import train_one_epoch, evaluate

### BEGIN SOLUTION

# use our dataset and defined transformations
dataset = VocDataset(data_path, get_transform(train=True))

# Import Subset
from torch.utils.data.dataset import Subset

# split the dataset in train and test set with torch.utils.data.Subset
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

train_size = 0.6

train_indices = indices[:int((len(dataset))*train_size)] 
test_indices = indices[int((len(dataset))*train_size):]

dataset_train = Subset(dataset, train_indices)
dataset_test = Subset(dataset, test_indices)

# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
                                                dataset_train,
                                                batch_size=4,
                                                shuffle=True,
                                                num_workers=2,
                                                collate_fn=utils.collate_fn
                                                ) # use a batch_size of 4, 2 workers and the shuffle option

data_loader_test = torch.utils.data.DataLoader(
                                                dataset_test,
                                                batch_size=4,
                                                shuffle=False,
                                                num_workers=2,
                                                collate_fn=utils.collate_fn
                                                ) # use a batch_size of 4, 2 workers and disable the shuffle option

### END SOLUTION

# %% [markdown]
# Then, instantiate the model and the optimizer.

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has 14 classes but bg class is set to 0
num_classes = 15

### BEGIN SOLUTION

# get the model using our helper function
model = get_detection_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer SGD with lr=0.005, momentum=0.9 and weight_decay=0.0005
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, 
                            lr=0.005, 
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

### END SOLUTION

# %% [markdown]
# And now let's train the model for 3 epochs, evaluating at the end of every epoch.
#
# It's time for you to take a 20 min break during the training.

# %%
# let's train it for 3 epochs
num_epochs = 3

### BEGIN SOLUTION

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations (use train_one_epoch function)
    train_one_epoch(model, optimizer, data_loader_train, device, num_epochs, 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset (use evaluate function)
    evaluate(model, data_loader_test, device)

### END SOLUTION
# Out:
# Epoch: [3]  [ 0/83]  eta: 0:04:23  lr: 0.005000  loss: 3.4668 (3.4668)  loss_classifier: 2.7619 (2.7619)  loss_box_reg: 0.6624 (0.6624)  loss_objectness: 0.0227 (0.0227)  loss_rpn_box_reg: 0.0198 (0.0198)  time: 3.1806  data: 0.2446  max mem: 5043
# Epoch: [3]  [10/83]  eta: 0:01:38  lr: 0.005000  loss: 1.2955 (1.3850)  loss_classifier: 0.7767 (0.9409)  loss_box_reg: 0.3781 (0.3647)  loss_objectness: 0.0361 (0.0592)  loss_rpn_box_reg: 0.0198 (0.0202)  time: 1.3488  data: 0.0360  max mem: 6880
# Epoch: [3]  [20/83]  eta: 0:01:25  lr: 0.005000  loss: 0.8539 (1.0605)  loss_classifier: 0.3834 (0.6425)  loss_box_reg: 0.2896 (0.3108)  loss_objectness: 0.0381 (0.0684)  loss_rpn_box_reg: 0.0219 (0.0388)  time: 1.2579  data: 0.0150  max mem: 6880
# Epoch: [3]  [30/83]  eta: 0:01:07  lr: 0.005000  loss: 0.7147 (0.9603)  loss_classifier: 0.3065 (0.5455)  loss_box_reg: 0.2534 (0.3094)  loss_objectness: 0.0517 (0.0632)  loss_rpn_box_reg: 0.0427 (0.0422)  time: 1.2233  data: 0.0147  max mem: 6880
# Epoch: [3]  [40/83]  eta: 0:00:54  lr: 0.005000  loss: 0.6913 (0.8772)  loss_classifier: 0.3065 (0.4817)  loss_box_reg: 0.2879 (0.3081)  loss_objectness: 0.0203 (0.0512)  loss_rpn_box_reg: 0.0211 (0.0362)  time: 1.1864  data: 0.0145  max mem: 7547
# Epoch: [3]  [50/83]  eta: 0:00:42  lr: 0.005000  loss: 0.6005 (0.8221)  loss_classifier: 0.2799 (0.4423)  loss_box_reg: 0.2879 (0.2993)  loss_objectness: 0.0150 (0.0466)  loss_rpn_box_reg: 0.0156 (0.0339)  time: 1.3367  data: 0.0164  max mem: 7547
# Epoch: [3]  [60/83]  eta: 0:00:29  lr: 0.005000  loss: 0.5713 (0.7848)  loss_classifier: 0.2651 (0.4102)  loss_box_reg: 0.2259 (0.2904)  loss_objectness: 0.0236 (0.0489)  loss_rpn_box_reg: 0.0227 (0.0352)  time: 1.3553  data: 0.0163  max mem: 7547
# Epoch: [3]  [70/83]  eta: 0:00:16  lr: 0.005000  loss: 0.4986 (0.7536)  loss_classifier: 0.2260 (0.3870)  loss_box_reg: 0.2259 (0.2836)  loss_objectness: 0.0350 (0.0475)  loss_rpn_box_reg: 0.0324 (0.0355)  time: 1.3370  data: 0.0140  max mem: 7547
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.4916 (0.7346)  loss_classifier: 0.2024 (0.3710)  loss_box_reg: 0.2401 (0.2827)  loss_objectness: 0.0285 (0.0445)  loss_rpn_box_reg: 0.0324 (0.0363)  time: 1.2966  data: 0.0142  max mem: 7547
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.4962 (0.7415)  loss_classifier: 0.2024 (0.3764)  loss_box_reg: 0.2415 (0.2822)  loss_objectness: 0.0281 (0.0466)  loss_rpn_box_reg: 0.0346 (0.0363)  time: 1.2400  data: 0.0137  max mem: 7547
# Epoch: [3] Total time: 0:01:46 (1.2858 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:46  model_time: 0.5240 (0.5240)  evaluator_time: 0.0177 (0.0177)  time: 0.8515  data: 0.3062  max mem: 7547
# Test:  [54/55]  eta: 0:00:00  model_time: 0.4951 (0.5477)  evaluator_time: 0.0175 (0.0183)  time: 0.5836  data: 0.0141  max mem: 7547
# Test: Total time: 0:00:32 (0.5902 s / it)
# Averaged stats: model_time: 0.4951 (0.5477)  evaluator_time: 0.0175 (0.0183)
# Accumulating evaluation results...
# DONE (t=0.31s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.093
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
# Epoch: [3]  [ 0/83]  eta: 0:01:59  lr: 0.005000  loss: 0.4153 (0.4153)  loss_classifier: 0.2004 (0.2004)  loss_box_reg: 0.1719 (0.1719)  loss_objectness: 0.0151 (0.0151)  loss_rpn_box_reg: 0.0280 (0.0280)  time: 1.4343  data: 0.2993  max mem: 7547
# Epoch: [3]  [10/83]  eta: 0:01:39  lr: 0.005000  loss: 0.7105 (0.6641)  loss_classifier: 0.3563 (0.3291)  loss_box_reg: 0.2646 (0.2581)  loss_objectness: 0.0413 (0.0423)  loss_rpn_box_reg: 0.0334 (0.0346)  time: 1.3606  data: 0.0399  max mem: 7921
# Epoch: [3]  [20/83]  eta: 0:01:24  lr: 0.005000  loss: 0.6445 (0.6103)  loss_classifier: 0.3056 (0.2935)  loss_box_reg: 0.2504 (0.2411)  loss_objectness: 0.0351 (0.0443)  loss_rpn_box_reg: 0.0288 (0.0314)  time: 1.3423  data: 0.0141  max mem: 7921
# Epoch: [3]  [30/83]  eta: 0:01:10  lr: 0.005000  loss: 0.4986 (0.5735)  loss_classifier: 0.2142 (0.2739)  loss_box_reg: 0.1732 (0.2284)  loss_objectness: 0.0255 (0.0372)  loss_rpn_box_reg: 0.0236 (0.0339)  time: 1.3248  data: 0.0143  max mem: 7921
# Epoch: [3]  [40/83]  eta: 0:00:58  lr: 0.005000  loss: 0.4876 (0.5631)  loss_classifier: 0.2142 (0.2670)  loss_box_reg: 0.2064 (0.2285)  loss_objectness: 0.0227 (0.0341)  loss_rpn_box_reg: 0.0198 (0.0335)  time: 1.3855  data: 0.0140  max mem: 7921
# Epoch: [3]  [50/83]  eta: 0:00:43  lr: 0.005000  loss: 0.4876 (0.5509)  loss_classifier: 0.2099 (0.2602)  loss_box_reg: 0.2104 (0.2253)  loss_objectness: 0.0233 (0.0325)  loss_rpn_box_reg: 0.0203 (0.0329)  time: 1.3064  data: 0.0141  max mem: 7921
# Epoch: [3]  [60/83]  eta: 0:00:30  lr: 0.005000  loss: 0.5315 (0.5604)  loss_classifier: 0.2229 (0.2661)  loss_box_reg: 0.2238 (0.2309)  loss_objectness: 0.0212 (0.0308)  loss_rpn_box_reg: 0.0227 (0.0326)  time: 1.2033  data: 0.0144  max mem: 7921
# Epoch: [3]  [70/83]  eta: 0:00:16  lr: 0.005000  loss: 0.4398 (0.5446)  loss_classifier: 0.2158 (0.2566)  loss_box_reg: 0.1973 (0.2264)  loss_objectness: 0.0191 (0.0294)  loss_rpn_box_reg: 0.0240 (0.0323)  time: 1.2227  data: 0.0140  max mem: 7921
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.4019 (0.5414)  loss_classifier: 0.1962 (0.2532)  loss_box_reg: 0.1828 (0.2268)  loss_objectness: 0.0172 (0.0279)  loss_rpn_box_reg: 0.0240 (0.0335)  time: 1.2819  data: 0.0142  max mem: 7921
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.4038 (0.5514)  loss_classifier: 0.1989 (0.2585)  loss_box_reg: 0.1855 (0.2303)  loss_objectness: 0.0172 (0.0284)  loss_rpn_box_reg: 0.0254 (0.0342)  time: 1.2720  data: 0.0137  max mem: 7921
# Epoch: [3] Total time: 0:01:47 (1.2996 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:44  model_time: 0.5092 (0.5092)  evaluator_time: 0.0171 (0.0171)  time: 0.8016  data: 0.2715  max mem: 7921
# Test:  [54/55]  eta: 0:00:00  model_time: 0.4958 (0.5531)  evaluator_time: 0.0153 (0.0152)  time: 0.5824  data: 0.0141  max mem: 7921
# Test: Total time: 0:00:32 (0.5921 s / it)
# Averaged stats: model_time: 0.4958 (0.5531)  evaluator_time: 0.0153 (0.0152)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.076
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.146
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.242
# Epoch: [3]  [ 0/83]  eta: 0:02:23  lr: 0.005000  loss: 0.4046 (0.4046)  loss_classifier: 0.1523 (0.1523)  loss_box_reg: 0.2218 (0.2218)  loss_objectness: 0.0117 (0.0117)  loss_rpn_box_reg: 0.0189 (0.0189)  time: 1.7304  data: 0.2691  max mem: 7921
# Epoch: [3]  [10/83]  eta: 0:01:37  lr: 0.005000  loss: 0.4575 (0.4730)  loss_classifier: 0.2230 (0.2202)  loss_box_reg: 0.2218 (0.2105)  loss_objectness: 0.0174 (0.0203)  loss_rpn_box_reg: 0.0208 (0.0221)  time: 1.3346  data: 0.0378  max mem: 7921
# Epoch: [3]  [20/83]  eta: 0:01:22  lr: 0.005000  loss: 0.4263 (0.4409)  loss_classifier: 0.1805 (0.2021)  loss_box_reg: 0.2013 (0.2001)  loss_objectness: 0.0154 (0.0167)  loss_rpn_box_reg: 0.0208 (0.0220)  time: 1.2899  data: 0.0159  max mem: 7921
# Epoch: [3]  [30/83]  eta: 0:01:08  lr: 0.005000  loss: 0.3830 (0.4467)  loss_classifier: 0.1668 (0.2041)  loss_box_reg: 0.1851 (0.2021)  loss_objectness: 0.0153 (0.0163)  loss_rpn_box_reg: 0.0217 (0.0242)  time: 1.2658  data: 0.0155  max mem: 7921
# Epoch: [3]  [40/83]  eta: 0:00:55  lr: 0.005000  loss: 0.3784 (0.4397)  loss_classifier: 0.1707 (0.2041)  loss_box_reg: 0.1653 (0.1969)  loss_objectness: 0.0122 (0.0147)  loss_rpn_box_reg: 0.0186 (0.0240)  time: 1.2544  data: 0.0138  max mem: 7921
# Epoch: [3]  [50/83]  eta: 0:00:41  lr: 0.005000  loss: 0.4400 (0.4517)  loss_classifier: 0.2108 (0.2088)  loss_box_reg: 0.2021 (0.2041)  loss_objectness: 0.0090 (0.0140)  loss_rpn_box_reg: 0.0186 (0.0248)  time: 1.2030  data: 0.0143  max mem: 7921
# Epoch: [3]  [60/83]  eta: 0:00:29  lr: 0.005000  loss: 0.4909 (0.4554)  loss_classifier: 0.2258 (0.2086)  loss_box_reg: 0.2021 (0.2042)  loss_objectness: 0.0099 (0.0134)  loss_rpn_box_reg: 0.0210 (0.0291)  time: 1.2365  data: 0.0141  max mem: 7921
# Epoch: [3]  [70/83]  eta: 0:00:16  lr: 0.005000  loss: 0.3730 (0.4486)  loss_classifier: 0.1843 (0.2056)  loss_box_reg: 0.1796 (0.2012)  loss_objectness: 0.0097 (0.0131)  loss_rpn_box_reg: 0.0157 (0.0287)  time: 1.2976  data: 0.0140  max mem: 7921
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.3501 (0.4460)  loss_classifier: 0.1631 (0.2044)  loss_box_reg: 0.1551 (0.2003)  loss_objectness: 0.0095 (0.0127)  loss_rpn_box_reg: 0.0147 (0.0285)  time: 1.3255  data: 0.0145  max mem: 7921
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.3447 (0.4449)  loss_classifier: 0.1631 (0.2047)  loss_box_reg: 0.1465 (0.1992)  loss_objectness: 0.0085 (0.0127)  loss_rpn_box_reg: 0.0147 (0.0283)  time: 1.2822  data: 0.0141  max mem: 7921
# Epoch: [3] Total time: 0:01:45 (1.2692 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:45  model_time: 0.5219 (0.5219)  evaluator_time: 0.0150 (0.0150)  time: 0.8310  data: 0.2843  max mem: 7921
# Test:  [54/55]  eta: 0:00:00  model_time: 0.5043 (0.5542)  evaluator_time: 0.0111 (0.0143)  time: 0.5787  data: 0.0135  max mem: 7921
# Test: Total time: 0:00:32 (0.5923 s / it)
# Averaged stats: model_time: 0.5043 (0.5542)  evaluator_time: 0.0111 (0.0143)
# Accumulating evaluation results...
# DONE (t=0.25s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.306

# %% [markdown]
# At each epoch, an evaluation process is launched to monitor the training. For the last epoch what AP do you get ?

# %% [markdown]
# # Answers
# We can see the AP on the last output of the cell above. Shortly, we get 0.059 AP for IoU in range [0.5 - 0.95].

# %% [markdown]
# ### Checkpoints
#
# We may now save the model and the state of optimizers and learning rate schedulers in order to continue training from where we left of. This is known as checkpointing.

# %%
torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'lr_scheduler_state_dict': lr_scheduler.state_dict(),
            }, 'checkpoint.pt')

# %% [markdown]
# We can then re-create model, optimizer and lr_scheduler from scratch and simply load their state from the checkpoint file we have just saved.
#
# In case you have not been able to train your model during the break or have lost your model for some reason we provide you a checkpoint from this link which you can download and upload it to Colab to continue with the lab: [https://drive.google.com/file/d/1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ/view?usp=sharing](https://drive.google.com/file/d/1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ/view?usp=sharing)
#
# We may download it directly to Colab by doing:
#
# ```
# gdown --id 1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ
# ```

# %%
model = get_detection_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params,
                            lr=0.005,
                            momentum=0.9,
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

checkpoint = torch.load('checkpoint.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
lr_scheduler.load_state_dict(checkpoint['lr_scheduler_state_dict'])
epoch = checkpoint['epoch']

model.eval()
# - or -
model.train()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=15, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=60, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Exercise 6: Visualize the result on an image
#
# Computer Vision has the great advantage to be visual. Le's check the prediction on a an image.

# %%
from torchvision.transforms.functional import convert_image_dtype

# Batch images
batch_int = torch.stack([img1_int])
batch = convert_image_dtype(batch_int, dtype=torch.float).to(device)

model = model.eval()

# Print images with model prediction
outputs = model(batch)
print(outputs)
# Out:
# [{'boxes': tensor([[189.8675, 215.1861, 264.2065, 250.7347],
#         [268.9965,  19.8444, 442.8294, 287.4693],
#         [256.2693,  12.3243, 433.3985, 283.4053],
#         [276.3137, 212.2203, 422.5833, 274.5239],
#         [275.0993, 213.0956, 422.6150, 271.8868],
#         [185.4108, 225.3910, 272.2299, 249.0692],
#         [165.6081, 211.8406, 281.7085, 250.3724],
#         [196.9517, 226.9694, 276.3842, 254.1760],
#         [184.1662,   8.9002, 491.7219, 321.6259],
#         [269.2704, 178.8721, 425.1650, 304.2523],
#         [285.7480, 128.0790, 440.6233, 258.9525],
#         [277.7882, 180.5803, 425.2712, 275.3875],
#         [269.9410, 176.9957, 426.1446, 262.6130],
#         [  0.0000, 220.0327,  29.1989, 227.6745],
#         [  1.7236, 220.2735,  29.3272, 226.9794],
#         [186.1168, 213.4911, 262.2090, 238.0487],
#         [194.5451, 209.4609, 271.3804, 254.4329],
#         [177.9982, 205.6007, 273.1682, 261.3015],
#         [269.4811,  93.5613, 418.8773, 281.1517],
#         [237.2929, 214.2334, 244.4409, 228.8806],
#         [265.6941, 109.9375, 424.9095, 319.6742],
#         [191.9830, 213.4067, 247.2203, 239.6762],
#         [275.9784, 213.4286, 408.6974, 265.3165],
#         [184.4816, 201.7854, 439.1552, 271.9962],
#         [264.2513, 111.4610, 425.1302, 306.6866],
#         [122.8673,   8.6354, 451.6339, 325.4580],
#         [281.7471, 136.1999, 432.2639, 257.6029],
#         [ 44.4609, 207.2010, 270.5677, 250.0818],
#         [157.8717, 112.9272, 473.4284, 285.9731],
#         [133.2960,  35.4681, 429.2274, 317.9569],
#         [260.9153, 221.7505, 423.5393, 316.0504],
#         [155.5703, 214.0774, 286.7426, 260.9419],
#         [ 30.7077, 203.7460, 277.7628, 247.9819],
#         [202.5535, 209.0288, 262.4776, 252.0608]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([14,  5,  2, 14,  4,  4,  4, 14,  5, 14,  5,  6,  4, 14,  4,  4,  6, 14,
#         14,  3,  6, 14,  6,  6,  4,  6,  2, 14,  5, 14,  4,  6,  6,  4],
#        device='cuda:0'), 'scores': tensor([0.6135, 0.5316, 0.4137, 0.3747, 0.3618, 0.3104, 0.2333, 0.2233, 0.2193,
#         0.2177, 0.1732, 0.1732, 0.1274, 0.1236, 0.1043, 0.1040, 0.1037, 0.0944,
#         0.0933, 0.0849, 0.0830, 0.0818, 0.0811, 0.0720, 0.0702, 0.0694, 0.0642,
#         0.0638, 0.0599, 0.0583, 0.0575, 0.0571, 0.0570, 0.0541],
#        device='cuda:0', grad_fn=<IndexBackward0>)}]

# %%
# Select minimum threshold for keeping bbox
score_threshold = .3
# Show boxes
imgs_with_boxes = [
    draw_bounding_boxes(img_int,
                        boxes=output['boxes'][output['scores'] > score_threshold],
                        width=4)
    for img_int, output in zip(batch_int, outputs)
]
show(imgs_with_boxes)

# %% [markdown]
# Play with the score threshold.
#
# Can you select a good trade-off threshold ?
#
# Can you think of a technique to remove the duplicated bounding boxes ?

# %%
# Apply the filtering solution
from torchvision import ops

### BEGIN SOLUTION
for img_int, output in zip(batch_int, outputs):
  toto = ops.nms(output['boxes'], output['scores'], iou_threshold=0.3)
  print(toto)

for img_int, output in zip(batch_int, outputs):
  print(output['boxes'][toto])
  print(output['scores'][toto])
### END SOLUTION
# Out:
# tensor([ 0,  1,  3, 13, 19, 27], device='cuda:0')
# tensor([[189.8675, 215.1861, 264.2065, 250.7347],
#         [268.9965,  19.8444, 442.8294, 287.4693],
#         [276.3137, 212.2203, 422.5833, 274.5239],
#         [  0.0000, 220.0327,  29.1989, 227.6745],
#         [237.2929, 214.2334, 244.4409, 228.8806],
#         [ 44.4609, 207.2010, 270.5677, 250.0818]], device='cuda:0',
#        grad_fn=<IndexBackward0>)
# tensor([0.6135, 0.5316, 0.3747, 0.1236, 0.0849, 0.0638], device='cuda:0',
#        grad_fn=<IndexBackward0>)

# %%
## Plot the filtered solution
# Select minimum threshold for keeping bbox
score_threshold = .5
# Show boxes
imgs_with_boxes = [
    draw_bounding_boxes(img_int,
                        boxes=output['boxes'][output['scores'] > score_threshold],
                        width=4)
    for img_int, output in zip(batch_int, outputs)
]
show(imgs_with_boxes)

# %% [markdown]
# ## Exercise 7: Create a MVP (Minimum Viable Product)
#
# To cope with the small unbalanced dataset we have, two solutions are available
#
# * Get more data on the internet or at sea, but we don't have time to search and annotate new data. Annotation is a faily time-consuming process. [Make a try](https://www.makesense.ai/)
# * Merge classes to simplify the problem and balance the data.
#
# For example in our case 14 categories is detailed. Indeed we want to be able to separate
#
# * small_vessel -> [boat, motor_sail, zodiac]
# * big_vessel -> [ferry, vessel, fishing_boat]
# * sail_vessel -> [sail, windsurf, kite]
# * human_powered_vessel -> [kayak, surfboard]
# * person
# * other -> [buoy, OFNI]
#
# ```
# TODO
# 1. Modify the dictionnary of annotations.
# 2. Modify the dataLoader class to implement that merging process.
# ```

# %%
# New maritime dictionnary for MVP
new_maritime_dict = {
    0: "small_vessel",
    1: "big_vessel",
    2: "sail_vessel",
    3: "human_powered_vessel",
    4: "person",
    5: "other"
}

# %%
# Create a dictionnary to convert labels
merging_dict = {
    0: 0,
    1: 5,
    2: 2,
    3: 4,
    4: 3,
    5: 0,
    6: 1,
    7: 1,
    8: 0,
    9: 1,
    10: 5,
    11: 2,
    12: 2,
    13: 3
}

# %% [markdown]
# Recreate count of all images to recreate class balance. You can use the function from exercise 1.

# %%
# Get annotations from txt files
def mvp_count_objects(data_path, merging_dict):
  """
  Function reading all txt files from a yolo format and returning number of objects by class

  <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
  <object-class> - integer number of object from 0 to (classes-1)
  <XCenterRelative> <YCenterRelative> - center of the bounding box [0,1]
  <WidthRelative> <HeightRelative> - width and height [0,1]
  """
  # Create class container
  classes = []

  ### BEGIN SOLUTION
  
  # Iterate over text file in a sorted list of files in a folder
  for filename in sorted(os.listdir(data_path)):
  
    # Check if the file format is '.txt' and is not the 'labels.txt', then create the file path
    if filename.endswith("txt") and filename != 'labels.txt': 
      file_path = data_path + filename

  # Iterate over the line in an opened txt.file
      with open(file_path) as f:
        lines = f.readlines()

        # Iterate over each line to get the class, then append it to the classes list
        for line in lines:
          im_class = line.split()[0]
          classes.append(int(im_class))
        
  ## Merging class
  # Create merging class container
  merging_classes = []

  # Iterate over merging_dict and change the class
  for im_class in classes:
    for key in merging_dict:
      # Grouping the class with the key of the merging dict
      if im_class == key:
        merging_classes.append(int(merging_dict[key]))
        continue

  # Create the dataframe form merged class
  df = pd.DataFrame(merging_classes)

  return df.value_counts()

  ### END SOLUTION

# %%
# apply count and rename classes
### BEGIN SOLUTION
mvp_count_df = mvp_count_objects(data_path, merging_dict)

# Change the name of index of the merging dict
mvp_count_df = mvp_count_df.rename(index=new_maritime_dict)

### END SOLUTION
assert mvp_count_df['sail_vessel'] == 170
mvp_count_df
# Out:
# small_vessel            592
# person                  572
# big_vessel              234
# human_powered_vessel    171
# sail_vessel             170
# other                   157
# dtype: int64

# %% [markdown]
# Now that we can see that the dataset is more balanced, let's modify the dataloader to modify the class during the loading of the data.

# %%
class mvp_VocDataset(torch.utils.data.Dataset):
  def __init__(self, root, merging_dict, transform=None):
    self.root = root
    self.transform = transform
    self.merging_dict = merging_dict
    # load all image files, sorting them to ensure that they are aligned
    self.imgs = list(sorted(Path(root).glob('*.jpg')))
    self.bboxes = list(sorted(Path(root).glob('*.txt')))[:-1] # ignore labels.txt


  def __getitem__(self, idx):

    # get image and bounding boxes paths
    img_path = os.path.join(self.imgs[idx])
    bbox_path = os.path.join(self.bboxes[idx])
    # open image and convert to RGB
    img = Image.open(img_path).convert("RGB")
    # get width and height
    width, height = img.size
    # get bounding boxes
    bbox_df = pd.read_csv(bbox_path, sep=' ', header=None)
        
    # get bounding box coordinates
    # YOLO format reminder :
    # <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
    boxes = []
    for index, row in bbox_df.iterrows():
      xmin = (row[1] - (row[3] / 2)) * width
      xmax = (row[1] + (row[3] / 2)) * width
      ymin = (row[2] - (row[4] / 2)) * height
      ymax = (row[2] + (row[4] / 2)) * height
      if xmin < xmax and ymin < ymax:
        boxes.append([xmin, ymin, xmax, ymax])

    # convert everything into a torch.Tensor
    boxes = torch.as_tensor(boxes, dtype=torch.float32)

    ## BEGIN SOLUTION

    # replace labels with new dict
    labels = bbox_df.loc[:,0].replace(merging_dict, inplace=True)
    # replace label 0 by 6
    labels = bbox_df.loc[:,0].replace(0, 6)
    # convert labels to a torch.Tensor
    labels = torch.Tensor(labels).type(torch.int64)

    ### END SOLUTION

    # get image od
    image_id = torch.tensor([idx])
    # compute area of the bounding boxes
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    # suppose all instances are not crowd
    iscrowd = torch.zeros((len(bbox_df),), dtype=torch.int64)

    # populate target dictionnary
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = image_id
    target["area"] = area
    target["iscrowd"] = iscrowd

    # image transformation
    if self.transform is not None:
      img, target = self.transform(img, target)

    return img, target


  def __len__(self):
    return len(self.imgs)

# %%
mvp_dataset = mvp_VocDataset(data_path, merging_dict, get_transform(train=True))
assert torch.equal(mvp_dataset[0][1]['labels'], torch.tensor([6,1]))
mvp_dataset[0]
# Out:
# (tensor([[[0.9686, 0.9490, 0.9647,  ..., 0.9490, 0.9529, 0.9608],
#           [0.9529, 0.9373, 0.9451,  ..., 0.9412, 0.9451, 0.9569],
#           [0.9490, 0.9294, 0.9412,  ..., 0.9333, 0.9373, 0.9490],
#           ...,
#           [0.2314, 0.2235, 0.2196,  ..., 0.5882, 0.5725, 0.5882],
#           [0.2235, 0.2157, 0.2235,  ..., 0.5765, 0.5569, 0.5922],
#           [0.2235, 0.2157, 0.2314,  ..., 0.5843, 0.5765, 0.5804]],
#
#          [[0.9686, 0.9490, 0.9647,  ..., 0.9490, 0.9529, 0.9608],
#           [0.9529, 0.9373, 0.9451,  ..., 0.9412, 0.9451, 0.9569],
#           [0.9490, 0.9294, 0.9412,  ..., 0.9333, 0.9373, 0.9490],
#           ...,
#           [0.2353, 0.2275, 0.2235,  ..., 0.6000, 0.5843, 0.6000],
#           [0.2275, 0.2196, 0.2275,  ..., 0.5882, 0.5686, 0.6039],
#           [0.2275, 0.2196, 0.2353,  ..., 0.5961, 0.5882, 0.5922]],
#
#          [[0.9686, 0.9490, 0.9647,  ..., 0.9412, 0.9451, 0.9529],
#           [0.9529, 0.9373, 0.9451,  ..., 0.9333, 0.9373, 0.9490],
#           [0.9490, 0.9294, 0.9412,  ..., 0.9255, 0.9294, 0.9412],
#           ...,
#           [0.1647, 0.1569, 0.1529,  ..., 0.5725, 0.5569, 0.5725],
#           [0.1569, 0.1490, 0.1569,  ..., 0.5608, 0.5412, 0.5765],
#           [0.1569, 0.1490, 0.1647,  ..., 0.5686, 0.5608, 0.5647]]]),
#  {'boxes': tensor([[ 63.0000,  10.9998, 226.0000, 278.9999],
#           [219.0000, 214.0001, 312.6580, 252.0001]]),
#   'labels': tensor([6, 1]),
#   'image_id': tensor([0]),
#   'area': tensor([43684.0117,  3559.0000]),
#   'iscrowd': tensor([0, 0])})

# %% [markdown]
# Labels [5, 6] have been transformed to [6, 1]

# %% [markdown]
# ## Exercise 8: Retrain the model
#
# Train the model with the new dataset.
#
# Take code already written in exercise 5 and modify it to train the model again.

# %% [markdown]
# Dataset Split

# %%
from engine import train_one_epoch, evaluate

### BEGIN SOLUTION

# use our dataset and defined transformations
mvp_dataset = mvp_VocDataset(data_path, merging_dict, get_transform(train=True))

# Import Subset
from torch.utils.data.dataset import Subset

# split the dataset in train and test set with torch.utils.data.Subset
torch.manual_seed(1)
mvp_indices = torch.randperm(len(mvp_dataset)).tolist()

mvp_train_size = 0.6

mvp_train_indices = mvp_indices[:int((len(mvp_dataset))*mvp_train_size)] 
mvp_test_indices = mvp_indices[int((len(mvp_dataset))*mvp_train_size):]

mvp_dataset_train = Subset(mvp_dataset, mvp_train_indices)
mvp_dataset_test = Subset(mvp_dataset, mvp_test_indices)

# define training and validation data loaders
mvp_data_loader_train = torch.utils.data.DataLoader(
                                                mvp_dataset_train,
                                                batch_size=4,
                                                shuffle=True,
                                                num_workers=2,
                                                collate_fn=utils.collate_fn
                                                ) # use a batch_size of 4, 2 workers and the shuffle option

mvp_data_loader_test = torch.utils.data.DataLoader(
                                                mvp_dataset_test,
                                                batch_size=4,
                                                shuffle=False,
                                                num_workers=2,
                                                collate_fn=utils.collate_fn
                                                ) # use a batch_size of 4, 2 workers and disable the shuffle option

### END SOLUTION

# %% [markdown]
# Set Model and Optimizer

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has 14 classes but bg class is set to 0
num_classes = 15

### BEGIN SOLUTION

# get the model using our helper function
mvp_model = get_detection_model(num_classes)
# move model to the right device
mvp_model.to(device)

# construct an optimizer SGD with lr=0.005, momentum=0.9 and weight_decay=0.0005
mvp_params = [p for p in mvp_model.parameters() if p.requires_grad]
mvp_optimizer = torch.optim.SGD(mvp_params, 
                            lr=0.005, 
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
mvp_lr_scheduler = torch.optim.lr_scheduler.StepLR(mvp_optimizer,
                                               step_size=3,
                                               gamma=0.1)

### END SOLUTION

# %% [markdown]
# Train

# %%
# let's train it for 3 epochs
num_epochs = 3

### BEGIN SOLUTION

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations (use train_one_epoch function)
    train_one_epoch(mvp_model, mvp_optimizer, mvp_data_loader_train, device, num_epochs, 10)
    # update the learning rate
    mvp_lr_scheduler.step()
    # evaluate on the test dataset (use evaluate function)
    evaluate(mvp_model, mvp_data_loader_test, device)

### END SOLUTION
# Out:
# Epoch: [3]  [ 0/83]  eta: 0:02:08  lr: 0.005000  loss: 3.5001 (3.5001)  loss_classifier: 2.8215 (2.8215)  loss_box_reg: 0.6361 (0.6361)  loss_objectness: 0.0227 (0.0227)  loss_rpn_box_reg: 0.0198 (0.0198)  time: 1.5498  data: 0.3076  max mem: 7921
# Epoch: [3]  [10/83]  eta: 0:01:32  lr: 0.005000  loss: 1.2720 (1.3640)  loss_classifier: 0.7064 (0.9335)  loss_box_reg: 0.3575 (0.3516)  loss_objectness: 0.0321 (0.0586)  loss_rpn_box_reg: 0.0198 (0.0203)  time: 1.2620  data: 0.0399  max mem: 8095
# Epoch: [3]  [20/83]  eta: 0:01:24  lr: 0.005000  loss: 0.8491 (1.0503)  loss_classifier: 0.3834 (0.6377)  loss_box_reg: 0.2733 (0.3070)  loss_objectness: 0.0375 (0.0667)  loss_rpn_box_reg: 0.0215 (0.0388)  time: 1.3288  data: 0.0137  max mem: 8095
# Epoch: [3]  [30/83]  eta: 0:01:08  lr: 0.005000  loss: 0.6820 (0.9454)  loss_classifier: 0.2949 (0.5374)  loss_box_reg: 0.2634 (0.3048)  loss_objectness: 0.0461 (0.0613)  loss_rpn_box_reg: 0.0442 (0.0420)  time: 1.2948  data: 0.0149  max mem: 8095
# Epoch: [3]  [40/83]  eta: 0:00:55  lr: 0.005000  loss: 0.6704 (0.8591)  loss_classifier: 0.2852 (0.4682)  loss_box_reg: 0.2919 (0.3051)  loss_objectness: 0.0211 (0.0499)  loss_rpn_box_reg: 0.0210 (0.0360)  time: 1.2476  data: 0.0148  max mem: 8765
# Epoch: [3]  [50/83]  eta: 0:00:43  lr: 0.005000  loss: 0.5821 (0.7985)  loss_classifier: 0.2521 (0.4256)  loss_box_reg: 0.2565 (0.2939)  loss_objectness: 0.0132 (0.0453)  loss_rpn_box_reg: 0.0147 (0.0337)  time: 1.3683  data: 0.0138  max mem: 8765
# Epoch: [3]  [60/83]  eta: 0:00:30  lr: 0.005000  loss: 0.5367 (0.7593)  loss_classifier: 0.2207 (0.3930)  loss_box_reg: 0.2194 (0.2852)  loss_objectness: 0.0164 (0.0459)  loss_rpn_box_reg: 0.0235 (0.0352)  time: 1.3502  data: 0.0138  max mem: 8765
# Epoch: [3]  [70/83]  eta: 0:00:17  lr: 0.005000  loss: 0.5066 (0.7275)  loss_classifier: 0.2093 (0.3696)  loss_box_reg: 0.2194 (0.2782)  loss_objectness: 0.0289 (0.0444)  loss_rpn_box_reg: 0.0312 (0.0354)  time: 1.3093  data: 0.0144  max mem: 8765
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.4880 (0.7083)  loss_classifier: 0.1990 (0.3523)  loss_box_reg: 0.2405 (0.2774)  loss_objectness: 0.0244 (0.0424)  loss_rpn_box_reg: 0.0348 (0.0362)  time: 1.2798  data: 0.0148  max mem: 8765
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.4956 (0.7129)  loss_classifier: 0.1990 (0.3560)  loss_box_reg: 0.2475 (0.2766)  loss_objectness: 0.0216 (0.0441)  loss_rpn_box_reg: 0.0354 (0.0362)  time: 1.2277  data: 0.0144  max mem: 8765
# Epoch: [3] Total time: 0:01:47 (1.2931 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:48  model_time: 0.5374 (0.5374)  evaluator_time: 0.0248 (0.0248)  time: 0.8745  data: 0.3086  max mem: 8765
# Test:  [54/55]  eta: 0:00:00  model_time: 0.5004 (0.5546)  evaluator_time: 0.0196 (0.0224)  time: 0.5929  data: 0.0132  max mem: 8765
# Test: Total time: 0:00:33 (0.6009 s / it)
# Averaged stats: model_time: 0.5004 (0.5546)  evaluator_time: 0.0196 (0.0224)
# Accumulating evaluation results...
# DONE (t=0.31s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.219
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.346
# Epoch: [3]  [ 0/83]  eta: 0:01:58  lr: 0.005000  loss: 0.3720 (0.3720)  loss_classifier: 0.1942 (0.1942)  loss_box_reg: 0.1368 (0.1368)  loss_objectness: 0.0160 (0.0160)  loss_rpn_box_reg: 0.0250 (0.0250)  time: 1.4335  data: 0.3175  max mem: 8765
# Epoch: [3]  [10/83]  eta: 0:01:37  lr: 0.005000  loss: 0.6857 (0.6408)  loss_classifier: 0.3483 (0.3234)  loss_box_reg: 0.2599 (0.2440)  loss_objectness: 0.0356 (0.0408)  loss_rpn_box_reg: 0.0331 (0.0325)  time: 1.3365  data: 0.0441  max mem: 9138
# Epoch: [3]  [20/83]  eta: 0:01:23  lr: 0.005000  loss: 0.6202 (0.5799)  loss_classifier: 0.3024 (0.2835)  loss_box_reg: 0.2414 (0.2285)  loss_objectness: 0.0301 (0.0374)  loss_rpn_box_reg: 0.0267 (0.0306)  time: 1.3282  data: 0.0153  max mem: 9138
# Epoch: [3]  [30/83]  eta: 0:01:10  lr: 0.005000  loss: 0.4985 (0.5428)  loss_classifier: 0.1804 (0.2586)  loss_box_reg: 0.1442 (0.2179)  loss_objectness: 0.0209 (0.0336)  loss_rpn_box_reg: 0.0222 (0.0327)  time: 1.3258  data: 0.0142  max mem: 9138
# Epoch: [3]  [40/83]  eta: 0:00:58  lr: 0.005000  loss: 0.4315 (0.5252)  loss_classifier: 0.1804 (0.2449)  loss_box_reg: 0.1542 (0.2166)  loss_objectness: 0.0188 (0.0310)  loss_rpn_box_reg: 0.0159 (0.0327)  time: 1.3942  data: 0.0144  max mem: 9138
# Epoch: [3]  [50/83]  eta: 0:00:43  lr: 0.005000  loss: 0.4315 (0.5140)  loss_classifier: 0.1969 (0.2394)  loss_box_reg: 0.1872 (0.2129)  loss_objectness: 0.0214 (0.0296)  loss_rpn_box_reg: 0.0242 (0.0321)  time: 1.3141  data: 0.0148  max mem: 9138
# Epoch: [3]  [60/83]  eta: 0:00:30  lr: 0.005000  loss: 0.4800 (0.5156)  loss_classifier: 0.2014 (0.2393)  loss_box_reg: 0.1877 (0.2158)  loss_objectness: 0.0243 (0.0286)  loss_rpn_box_reg: 0.0242 (0.0320)  time: 1.2050  data: 0.0150  max mem: 9138
# Epoch: [3]  [70/83]  eta: 0:00:16  lr: 0.005000  loss: 0.4188 (0.5035)  loss_classifier: 0.1837 (0.2313)  loss_box_reg: 0.1877 (0.2127)  loss_objectness: 0.0182 (0.0276)  loss_rpn_box_reg: 0.0202 (0.0319)  time: 1.2250  data: 0.0148  max mem: 9138
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.3894 (0.5011)  loss_classifier: 0.1718 (0.2274)  loss_box_reg: 0.1721 (0.2142)  loss_objectness: 0.0140 (0.0264)  loss_rpn_box_reg: 0.0202 (0.0331)  time: 1.2822  data: 0.0146  max mem: 9138
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.3900 (0.5119)  loss_classifier: 0.1827 (0.2332)  loss_box_reg: 0.1799 (0.2179)  loss_objectness: 0.0140 (0.0269)  loss_rpn_box_reg: 0.0218 (0.0339)  time: 1.2726  data: 0.0140  max mem: 9138
# Epoch: [3] Total time: 0:01:47 (1.2990 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:46  model_time: 0.5363 (0.5363)  evaluator_time: 0.0215 (0.0215)  time: 0.8386  data: 0.2772  max mem: 9138
# Test:  [54/55]  eta: 0:00:00  model_time: 0.5045 (0.5558)  evaluator_time: 0.0128 (0.0148)  time: 0.5833  data: 0.0133  max mem: 9138
# Test: Total time: 0:00:32 (0.5945 s / it)
# Averaged stats: model_time: 0.5045 (0.5558)  evaluator_time: 0.0128 (0.0148)
# Accumulating evaluation results...
# DONE (t=0.25s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.125
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.372
# Epoch: [3]  [ 0/83]  eta: 0:02:22  lr: 0.005000  loss: 0.3574 (0.3574)  loss_classifier: 0.1378 (0.1378)  loss_box_reg: 0.2007 (0.2007)  loss_objectness: 0.0036 (0.0036)  loss_rpn_box_reg: 0.0153 (0.0153)  time: 1.7144  data: 0.2662  max mem: 9138
# Epoch: [3]  [10/83]  eta: 0:01:37  lr: 0.005000  loss: 0.4084 (0.4255)  loss_classifier: 0.1867 (0.1839)  loss_box_reg: 0.2000 (0.1976)  loss_objectness: 0.0197 (0.0220)  loss_rpn_box_reg: 0.0213 (0.0219)  time: 1.3332  data: 0.0391  max mem: 9138
# Epoch: [3]  [20/83]  eta: 0:01:22  lr: 0.005000  loss: 0.4060 (0.4055)  loss_classifier: 0.1666 (0.1769)  loss_box_reg: 0.1775 (0.1889)  loss_objectness: 0.0186 (0.0175)  loss_rpn_box_reg: 0.0171 (0.0221)  time: 1.2882  data: 0.0150  max mem: 9138
# Epoch: [3]  [30/83]  eta: 0:01:08  lr: 0.005000  loss: 0.3740 (0.4104)  loss_classifier: 0.1591 (0.1772)  loss_box_reg: 0.1632 (0.1912)  loss_objectness: 0.0144 (0.0174)  loss_rpn_box_reg: 0.0200 (0.0246)  time: 1.2666  data: 0.0145  max mem: 9138
# Epoch: [3]  [40/83]  eta: 0:00:55  lr: 0.005000  loss: 0.3740 (0.4033)  loss_classifier: 0.1515 (0.1784)  loss_box_reg: 0.1483 (0.1853)  loss_objectness: 0.0129 (0.0155)  loss_rpn_box_reg: 0.0200 (0.0240)  time: 1.2574  data: 0.0151  max mem: 9138
# Epoch: [3]  [50/83]  eta: 0:00:41  lr: 0.005000  loss: 0.3915 (0.4139)  loss_classifier: 0.1706 (0.1813)  loss_box_reg: 0.1736 (0.1922)  loss_objectness: 0.0111 (0.0154)  loss_rpn_box_reg: 0.0185 (0.0250)  time: 1.2037  data: 0.0145  max mem: 9138
# Epoch: [3]  [60/83]  eta: 0:00:29  lr: 0.005000  loss: 0.4578 (0.4175)  loss_classifier: 0.1921 (0.1817)  loss_box_reg: 0.1855 (0.1920)  loss_objectness: 0.0132 (0.0149)  loss_rpn_box_reg: 0.0204 (0.0289)  time: 1.2384  data: 0.0153  max mem: 9138
# Epoch: [3]  [70/83]  eta: 0:00:16  lr: 0.005000  loss: 0.3702 (0.4096)  loss_classifier: 0.1804 (0.1776)  loss_box_reg: 0.1533 (0.1884)  loss_objectness: 0.0111 (0.0149)  loss_rpn_box_reg: 0.0164 (0.0287)  time: 1.2986  data: 0.0158  max mem: 9138
# Epoch: [3]  [80/83]  eta: 0:00:03  lr: 0.005000  loss: 0.3410 (0.4089)  loss_classifier: 0.1728 (0.1778)  loss_box_reg: 0.1519 (0.1880)  loss_objectness: 0.0107 (0.0147)  loss_rpn_box_reg: 0.0132 (0.0284)  time: 1.3263  data: 0.0153  max mem: 9138
# Epoch: [3]  [82/83]  eta: 0:00:01  lr: 0.005000  loss: 0.3206 (0.4076)  loss_classifier: 0.1728 (0.1782)  loss_box_reg: 0.1457 (0.1866)  loss_objectness: 0.0107 (0.0146)  loss_rpn_box_reg: 0.0132 (0.0281)  time: 1.2830  data: 0.0145  max mem: 9138
# Epoch: [3] Total time: 0:01:45 (1.2701 s / it)
# creating index...
# index created!
# Test:  [ 0/55]  eta: 0:00:46  model_time: 0.5271 (0.5271)  evaluator_time: 0.0136 (0.0136)  time: 0.8518  data: 0.3057  max mem: 9138
# Test:  [54/55]  eta: 0:00:00  model_time: 0.5031 (0.5549)  evaluator_time: 0.0119 (0.0147)  time: 0.5856  data: 0.0139  max mem: 9138
# Test: Total time: 0:00:32 (0.5938 s / it)
# Averaged stats: model_time: 0.5031 (0.5549)  evaluator_time: 0.0119 (0.0147)
# Accumulating evaluation results...
# DONE (t=0.21s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.207
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.396

# %% [markdown]
# Can you explain the new AP score of the model on this simpler dataset ?
#
# # Answers
# In general, AP score on the newer model seems relatively higher. But to be more specific, in term of image scales, The newer model is better at predicting "large", or very close, object (0.181 compared t0 0.122). Newer model is also better at predicting "medium", or not far away, object (0.078 compared to 0.046). However both model seems to have similar performance on 'small', or very far away, object (0.048 compared to 0.046).

# %% [markdown]
# ## Exercise 9: Test on new images
#
# Take images on Google or where you want to apply the model on it, in a maritime context or in completely different one.
#
# Try to answer those questions with empirical test:
#
# 1. Is the model good on all situation ?
# 2. Can you see a difference on small/medium/large objects ?
# 3. Can you isolate difficult images for it ?
# 4. Easy ones ?
# 5. Do you have good accuracy on different weather ?
# 6. Considering your answers how could you improve the dataset to improve the training of the model ?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load new folder for test photo
new_data_path = '/content/drive/MyDrive/MIR/test_photos/'

# Create directory list for the new test photos
test_photo_list = list(sorted(Path(new_data_path).glob('*.jpg')))

# %%
from torchvision.transforms.functional import convert_image_dtype

# Set the device to GPU
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Get the image to predict 
img_to_predict = read_image(str(test_photo_list[30]))

# Batch images
new_batch_int = torch.stack([img_to_predict])
new_batch = convert_image_dtype(new_batch_int, dtype=torch.float).to(device)

# Set the model to evaluation mode
model = model.eval()

# Print images with model prediction
new_outputs = model(new_batch)

# %%
# Select minimum threshold for keeping bbox
score_threshold = .1
# Show boxes
new_imgs_with_boxes = [
    draw_bounding_boxes(new_img_int,
                        boxes=new_output['boxes'][new_output['scores'] > score_threshold],
                        width=4)
    for new_img_int, new_output in zip(new_batch_int, new_outputs)
]
show(new_imgs_with_boxes)

# %%
# Do the Non Max Surpression
from torchvision import ops

### BEGIN SOLUTION
for new_img_int, new_output in zip(new_batch_int, new_outputs):
  new_toto = ops.nms(new_output['boxes'], new_output['scores'], iou_threshold=.5)
  print(new_toto)

for new_img_int, new_output in zip(new_batch_int, new_outputs):
  print(new_output['boxes'][new_toto])
  print(new_output['scores'][new_toto])
  print(new_output['labels'][new_toto])
### END SOLUTION
# Out:
# tensor([ 0,  1,  2,  3,  4,  7,  9, 11, 12, 13, 14, 17, 21, 22, 26, 28, 29, 32,
#         34, 38, 39, 40, 42, 43, 46, 50, 54, 55, 57, 59, 60, 65, 69, 70, 71, 73,
#         74, 77, 82, 85, 92, 94, 95, 97], device='cuda:0')
# tensor([[1.5799e+03, 8.9849e+02, 1.6191e+03, 9.3055e+02],
#         [5.9848e+02, 1.3363e+02, 1.3624e+03, 1.0454e+03],
#         [1.2700e+02, 8.8156e+02, 1.5928e+02, 9.1546e+02],
#         [4.2296e+02, 9.7416e+02, 5.3605e+02, 1.0759e+03],
#         [7.3306e-01, 8.8927e+02, 4.0972e+02, 9.7854e+02],
#         [1.2336e+03, 1.0855e+03, 1.3458e+03, 1.1056e+03],
#         [6.0355e+02, 1.0803e+03, 6.9477e+02, 1.0957e+03],
#         [4.0400e+02, 5.9871e+02, 7.1671e+02, 1.0441e+03],
#         [1.1946e+03, 1.0885e+03, 1.2438e+03, 1.1034e+03],
#         [1.0681e+03, 3.7627e+02, 1.4721e+03, 1.0149e+03],
#         [4.3668e+02, 9.3358e+02, 6.2629e+02, 1.0285e+03],
#         [5.1297e+02, 1.0754e+03, 5.5639e+02, 1.0908e+03],
#         [5.5169e+02, 1.0805e+03, 6.0675e+02, 1.0921e+03],
#         [4.3309e+02, 3.6743e+02, 1.0906e+03, 1.0714e+03],
#         [1.1881e+03, 1.0859e+03, 1.4593e+03, 1.1090e+03],
#         [1.2366e+03, 1.0848e+03, 1.2604e+03, 1.1057e+03],
#         [5.7772e+02, 8.9444e+02, 9.1037e+02, 1.0235e+03],
#         [4.2671e+02, 9.4285e+02, 5.8575e+02, 1.0912e+03],
#         [3.6104e+02, 5.4746e+02, 9.5391e+02, 1.0225e+03],
#         [5.2745e+02, 1.0779e+03, 6.0499e+02, 1.0939e+03],
#         [1.3260e+03, 1.0878e+03, 1.4404e+03, 1.1028e+03],
#         [2.0367e+02, 8.7659e+02, 2.2770e+02, 9.1202e+02],
#         [1.4297e+03, 1.0901e+03, 1.5417e+03, 1.1032e+03],
#         [3.9458e+01, 8.8232e+02, 6.7530e+01, 9.1156e+02],
#         [5.8154e+02, 1.0758e+03, 8.2612e+02, 1.1008e+03],
#         [7.7318e+02, 3.9846e+02, 1.4529e+03, 1.0864e+03],
#         [6.0228e+02, 1.0789e+03, 6.2862e+02, 1.0983e+03],
#         [1.4178e+03, 1.0888e+03, 1.5954e+03, 1.1075e+03],
#         [1.5774e+03, 8.8830e+02, 1.6332e+03, 9.4252e+02],
#         [1.9664e+02, 9.4685e+02, 3.8526e+02, 1.1126e+03],
#         [8.2567e+02, 6.2143e+02, 1.2325e+03, 1.0767e+03],
#         [5.2859e+02, 1.0772e+03, 5.5662e+02, 1.0940e+03],
#         [1.1198e+03, 1.0821e+03, 1.3734e+03, 1.1065e+03],
#         [6.7614e+01, 6.2693e+02, 8.7840e+02, 1.0034e+03],
#         [1.3973e+03, 1.0854e+03, 1.7106e+03, 1.1085e+03],
#         [3.8129e+01, 8.9370e+02, 5.5094e+01, 9.0886e+02],
#         [4.6538e+02, 1.0653e+03, 6.6614e+02, 1.0983e+03],
#         [6.0310e+02, 1.0756e+03, 7.0650e+02, 1.0904e+03],
#         [4.5710e+02, 1.0459e+03, 5.3827e+02, 1.0723e+03],
#         [9.5712e+02, 1.0835e+03, 1.1362e+03, 1.1116e+03],
#         [1.1400e+03, 1.0869e+03, 1.2415e+03, 1.1049e+03],
#         [1.6798e+03, 1.0866e+03, 1.8252e+03, 1.1046e+03],
#         [1.5761e+03, 1.0876e+03, 1.7102e+03, 1.1054e+03],
#         [9.9601e+01, 8.8461e+02, 1.2719e+02, 9.1311e+02]], device='cuda:0',
#        grad_fn=<IndexBackward0>)
# tensor([0.5425, 0.5020, 0.3336, 0.2928, 0.2840, 0.2518, 0.2283, 0.2111, 0.2030,
#         0.1993, 0.1973, 0.1907, 0.1744, 0.1615, 0.1496, 0.1431, 0.1418, 0.1361,
#         0.1214, 0.1185, 0.1160, 0.1157, 0.1142, 0.1138, 0.1070, 0.1027, 0.0973,
#         0.0965, 0.0932, 0.0898, 0.0880, 0.0826, 0.0801, 0.0782, 0.0775, 0.0740,
#         0.0739, 0.0719, 0.0685, 0.0653, 0.0608, 0.0601, 0.0594, 0.0592],
#        device='cuda:0', grad_fn=<IndexBackward0>)
# tensor([14,  2,  3, 14, 14, 14,  4, 14,  4,  2, 14,  4,  4, 14, 14,  3,  4, 14,
#         14,  4,  4,  3,  4,  3, 14,  2,  1, 14, 14,  4,  4,  4,  4, 14, 14,  1,
#         14,  4,  4, 14,  4,  4,  4,  3], device='cuda:0')

# %% [markdown]
# # Use this cell to do object detection validation

# %%
## Plot the filtered solution
# Select minimum threshold for keeping bbox
score_threshold = .5

# Show boxes
new_imgs_with_boxes = [
    draw_bounding_boxes(new_img_int,
                        boxes=new_output['boxes'][new_toto][new_output['scores'][new_toto] > score_threshold],
                        width=4)
    for new_img_int, new_output in zip(new_batch_int, new_outputs)
]

# Show new image with boxes
show(new_imgs_with_boxes)

# %% [markdown]
# # Answer to the question
# 1. Most of the time yes. Model can detect the object in a relatively different lighting (see picture 36, despite the dark surrounding and unusual lighting, model still can seperate the 'sail' and 'person'). Model can also detect and classify unusual type of object and able to closely predict the object (see picture 30, it predict the trimaran type ship as 'boat').
#
# 2. Yes, I have included several photos with lots of objects inside like big vessel, fishing boat, sail boat, etc. Both close and in distance. There are some instances where model can differentiate all. But there are some cases where the model can't detect the objects. Mainly because of high-contrast image, clipping (due to wave/ blocked by other objects) and odd shape (like the trimaran ship example)
#
# 3. Yes. (see picture [10] and [14])
#
# 4. Also yes. (see picture [28])
#
# 5. On the picture [36], we can see the score for obtained box are: 0.8641 for 'sail' and 0.8105 for 'person'.
#
# 6. Do more image augmentation, like flipping, change the contrast, and resizing (like scale down so the model can predict object in far away distances.

# %% [markdown]
# ## Optional Exercise 10: Train another model of your choice
#
# To go deeper with object detection, you can try different models. A list of all available models is accessible in the [model zoo](https://pytorch.org/vision/stable/models.html).
#
# Do a benchmark of the three models used so far.
# What is the best accuracy ? best speed ? ...
